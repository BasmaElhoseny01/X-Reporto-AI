# %% [markdown]
# # Clone Repository

# %%
# !wget -r -N -c -np --user ahmed-sabry --ask-password https://physionet.org/files/mimic-cxr/2.0.0/
# #D6zQ3c@J#Be$y5_
# to connect to drive
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://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:@github.com/BasmaElhoseny01/Graduation-Project
# !ls
# %cd Graduation-Project/
# !ls
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Create Needed Folders

# %%
import os
import shutil
from paths import path_chest_imagenome, path_mimic_cxr, path_mimic_cxr_jpg
import subprocess
# create folders in paths if they don't exist
def create_folders(paths):
    print("start")
    for path in paths:
        if not os.path.exists(path):
            os.makedirs(path)
            print("created successfully path: ",path)

create_folders([path_chest_imagenome, path_mimic_cxr, path_mimic_cxr_jpg])
# Out:
# start
# created successfully path:  datasets/chest-imagenome-dataset
# created successfully path:  datasets/mimic-cxr
# created successfully path:  datasets/mimic-cxr-jpg

# %% [markdown]
# # Download dataset from Drive

# %%
# !python -u ./load_datasets.py
# !unzip "/content/drive/MyDrive/MIMIC/p11_subset2.zip" -d "datasets/mimic-cxr-jpg"
# !unzip "/content/drive/MyDrive/MIMIC/chest-imagenome-dataset-1.0.0.zip" -d "datasets/"
os.rename("datasets/chest-imagenome-dataset-1.0.0","datasets/chest-imagenome-dataset")
# !unzip "datasets/chest-imagenome-dataset/silver_dataset/scene_graph.zip" -d "datasets/chest-imagenome-dataset/silver_dataset/"
# !unzip "/content/drive/MyDrive/MIMIC/mimic-cxr-reports.zip" -d "datasets/mimic-cxr"

# %% [markdown]
# # Rename Folders

# %%
def move_subfolder_to_parent_folder(subfolder_path, parent_folder_path):
    # move subfolder directly under parent folder as cut and paste
    shutil.move(subfolder_path, parent_folder_path)

move_subfolder_to_parent_folder(path_mimic_cxr_jpg + "/physionet.org/files/mimic-cxr-jpg/2.0.0/files", path_mimic_cxr_jpg)

# %% [markdown]
# # Run Dataset Creation Script

# %%
# !pip install -U spacy
# !pip install spacy-transformers
# !python -m spacy download en_core_web_trf
import spacy
import spacy_transformers



# from data_preprocessing.create import DataPreprocessing
# DataPreprocessor = DataPreprocessing(train_only=True)
# DataPreprocessor.create_new_csv_files()
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Collecting spacy
#   Downloading spacy-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.4)
# Installing collected packages: cloudpathlib, weasel, spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.7.2 which is incompatible.
# Successfully installed cloudpathlib-0.16.0 spacy-3.7.2 weasel-0.3.4
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (3.7.2)
# Requirement already satisfied: transformers<4.37.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (4.35.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (2.1.0+cu121)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (2.4.8)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers)
#   Downloading spacy_alignments-0.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (1.23.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.5.0->spacy-transformers) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->spacy-transformers) (1.3.0)
# Installing collected packages: spacy-alignments, spacy-transformers
# Successfully installed spacy-alignments-0.9.1 spacy-transformers-1.3.4
# 2024-02-01 18:33:53.623619: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 18:33:53.623686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 18:33:53.626047: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-01 18:33:53.636389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-01 18:33:55.417554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-trf==3.7.3) (3.7.2)
# Collecting spacy-curated-transformers<0.3.0,>=0.2.0 (from en-core-web-trf==3.7.3)
#   Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.23.5)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_tokenizers-0.0.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.6/731.6 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.1.0+cu121)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.10/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.6.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.7.3 spacy-curated-transformers-0.2.2
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
ST:|FRONTAL UPPER ABDOMINAL RADIOGRAPH, TWO IMAGES:|FRONTAL SUPINE PORTABLE CHEST:|FRONTAL SEMI-UPRIGHT PORTABLE CHEST:|FRONTAL RADIOGRAPH OF THE CHEST:|FRONTAL PORTABLE SUPINE CHEST:|FRONTAL PORTABLE CHEST:|FRONTAL PORTABLE CHEST RADIOGRAPH:|FRONTAL LATERAL VIEWS CHEST:|FRONTAL LATERAL CHEST RADIOGRAPH:|FRONTAL CHEST RADIOGRAPHS:|FRONTAL CHEST RADIOGRAPH:|FRONTAL CHEST RADIOGRAPH WITH THE PATIENT IN SUPINE AND UPRIGHT POSITIONS:|FRONTAL AND LATERAL VIEWS OF THE CHEST:|FRONTAL AND LATERAL FRONTAL CHEST RADIOGRAPH:|FRONTAL AND LATERAL CHEST RADIOGRAPHS:|FRONTAL AND LATERAL CHEST RADIOGRAPH:|FRONTAL|FINIDNGS:|FINDNGS:|FINDINGS:|FINDINGS/IMPRESSION:|FINDINGS AND IMPRESSION:|FINDINGS|FINDING:|FINAL REPORT FINDINGS:|FINAL REPORT EXAMINATION:|FINAL REPORT|FINAL ADDENDUM ADDENDUM:|FINAL ADDENDUM ADDENDUM|FINAL ADDENDUM \*\*\*\*\*\*\*\*\*\*ADDENDUM\*\*\*\*\*\*\*\*\*\*\*|FINAL ADDENDUM|EXAMINATION: DX CHEST PORT LINE/TUBE PLCMT 1 EXAM|CONCLUSION:|COMPARISONS:|COMPARISON:|COMPARISON.|CHEST:|CHEST/ABDOMEN RADIOGRAPHS:|CHEST, TWO VIEWS:|CHEST, SINGLE AP PORTABLE VIEW:|CHEST, PA AND LATERAL:|CHEST, AP:|CHEST, AP UPRIGHT:|CHEST, AP UPRIGHT AND LATERAL:|CHEST, AP SUPINE:|CHEST, AP SEMI-UPRIGHT:|CHEST, AP PORTABLE, UPRIGHT:|CHEST, AP AND LATERAL:|CHEST SUPINE:|CHEST RADIOGRAPH:|CHEST PA AND LATERAL RADIOGRAPH:|CHEST AP:|BEDSIDE UPRIGHT FRONTAL CHEST RADIOGRAPH:|AP:|AP,|AP VIEW OF THE CHEST:|AP UPRIGHT PORTABLE CHEST RADIOGRAPH:|AP UPRIGHT CHEST RADIOGRAPH:|AP UPRIGHT AND LATERAL CHEST RADIOGRAPHS:|AP PORTABLE SUPINE CHEST RADIOGRAPH:|AP PORTABLE CHEST RADIOGRAPH:|AP FRONTAL CHEST RADIOGRAPH:|AP CHEST:|AP CHEST RADIOGRAPH:|AP AND LATERAL VIEWS OF THE CHEST:|AP AND LATERAL CHEST RADIOGRAPHS:|AP AND LATERAL CHEST RADIOGRAPH:|5. |4. |3. |2. |1. |#1 |#2 |#3 |#4 |#5 "

# %%
"""
Copied directly from https://github.com/MIT-LCP/mimic-cxr/blob/master/txt/section_parser.py

The section_text is used in create_dataset.py to extract the findings section of the MIMIC-CXR reports,
which serve as the reference reports during evaluation.
"""
import re


def section_text(text):
    """Splits text into sections.
    Assumes text is in a radiology report format, e.g.:
        COMPARISON:  Chest radiograph dated XYZ.
        IMPRESSION:  ABC...
    Given text like this, it will output text from each section,
    where the section type is determined by the all caps header.
    Returns a three element tuple:
        sections - list containing the text of each section
        section_names - a normalized version of the section name
        section_idx - list of start indices of the text in the section
    """
    p_section = re.compile(
        r'\n ([A-Z ()/,-]+):\s', re.DOTALL)

    sections = list()
    section_names = list()
    section_idx = list()

    idx = 0
    s = p_section.search(text, idx)

    if s:
        sections.append(text[0:s.start(1)])
        section_names.append('preamble')
        section_idx.append(0)

        while s:
            current_section = s.group(1).lower()
            # get the start of the text for this section
            idx_start = s.end()
            # skip past the first newline to avoid some bad parses
            idx_skip = text[idx_start:].find('\n')
            if idx_skip == -1:
                idx_skip = 0

            s = p_section.search(text, idx_start + idx_skip)

            if s is None:
                idx_end = len(text)
            else:
                idx_end = s.start()

            sections.append(text[idx_start:idx_end])
            section_names.append(current_section)
            section_idx.append(idx_start)

    else:
        sections.append(text)
        section_names.append('full report')
        section_idx.append(0)

    section_names = normalize_section_names(section_names)

    # remove empty sections
    # this handles when the report starts with a finding-like statement
    #  .. but this statement is not a section, more like a report title
    #  e.g. p10/p10103318/s57408307
    #    CHEST, PA LATERAL:
    #
    #    INDICATION:   This is the actual section ....
    # it also helps when there are multiple findings sections
    # usually one is empty
    for i in reversed(range(len(section_names))):
        if section_names[i] in ('impression', 'findings'):
            if sections[i].strip() == '':
                sections.pop(i)
                section_names.pop(i)
                section_idx.pop(i)

    if ('impression' not in section_names) & ('findings' not in section_names):
        # create a new section for the final paragraph
        if '\n \n' in sections[-1]:
            sections.append('\n \n'.join(sections[-1].split('\n \n')[1:]))
            sections[-2] = sections[-2].split('\n \n')[0]
            section_names.append('last_paragraph')
            section_idx.append(section_idx[-1] + len(sections[-2]))

    return sections, section_names, section_idx


def normalize_section_names(section_names):
    # first, lower case all
    section_names = [s.lower().strip() for s in section_names]

    frequent_sections = {
        "preamble": "preamble",  # 227885
        "impression": "impression",  # 187759
        "comparison": "comparison",  # 154647
        "indication": "indication",  # 153730
        "findings": "findings",  # 149842
        "examination": "examination",  # 94094
        "technique": "technique",  # 81402
        "history": "history",  # 45624
        "comparisons": "comparison",  # 8686
        "clinical history": "history",  # 7121
        "reason for examination": "indication",  # 5845
        "notification": "notification",  # 5749
        "reason for exam": "indication",  # 4430
        "clinical information": "history",  # 4024
        "exam": "examination",  # 3907
        "clinical indication": "indication",  # 1945
        "conclusion": "impression",  # 1802
        "chest, two views": "findings",  # 1735
        "recommendation(s)": "recommendations",  # 1700
        "type of examination": "examination",  # 1678
        "reference exam": "comparison",  # 347
        "patient history": "history",  # 251
        "addendum": "addendum",  # 183
        "comparison exam": "comparison",  # 163
        "date": "date",  # 108
        "comment": "comment",  # 88
        "findings and impression": "impression",  # 87
        "wet read": "wet read",  # 83
        "comparison film": "comparison",  # 79
        "recommendations": "recommendations",  # 72
        "findings/impression": "impression",  # 47
        "pfi": "history",
        'recommendation': 'recommendations',
        'wetread': 'wet read',
        'ndication': 'impression',  # 1
        'impresson': 'impression',  # 2
        'imprression': 'impression',  # 1
        'imoression': 'impression',  # 1
        'impressoin': 'impression',  # 1
        'imprssion': 'impression',  # 1
        'impresion': 'impression',  # 1
        'imperssion': 'impression',  # 1
        'mpression': 'impression',  # 1
        'impession': 'impression',  # 3
        'findings/ impression': 'impression',  # ,1
        'finding': 'findings',  # ,8
        'findins': 'findings',
        'findindgs': 'findings',  # ,1
        'findgings': 'findings',  # ,1
        'findngs': 'findings',  # ,1
        'findnings': 'findings',  # ,1
        'finidngs': 'findings',  # ,2
        'idication': 'indication',  # ,1
        'reference findings': 'findings',  # ,1
        'comparision': 'comparison',  # ,2
        'comparsion': 'comparison',  # ,1
        'comparrison': 'comparison',  # ,1
        'comparisions': 'comparison'  # ,1
    }

    p_findings = [
        'chest',
        'portable',
        'pa and lateral',
        'lateral and pa',
        'ap and lateral',
        'lateral and ap',
        'frontal and',
        'two views',
        'frontal view',
        'pa view',
        'ap view',
        'one view',
        'lateral view',
        'bone window',
        'frontal upright',
        'frontal semi-upright',
        'ribs',
        'pa and lat'
    ]
    p_findings = re.compile('({})'.format('|'.join(p_findings)))

    main_sections = [
        'impression', 'findings', 'history', 'comparison',
        'addendum'
    ]
    for i, s in enumerate(section_names):
        if s in frequent_sections:
            section_names[i] = frequent_sections[s]
            continue

        main_flag = False
        for m in main_sections:
            if m in s:
                section_names[i] = m
                main_flag = True
                break
        if main_flag:
            continue

        m = p_findings.search(s)
        if m is not None:
            section_names[i] = 'findings'

        # if it looks like it is describing the entire study
        # it's equivalent to findings
        # group similar phrasings for impression

    return section_names


def custom_mimic_cxr_rules():
    custom_section_names = {
        's50913680': 'recommendations',  # files/p11/p11851243/s50913680.txt
        's59363654': 'examination',  # files/p12/p12128253/s59363654.txt
        's59279892': 'technique',  # files/p13/p13150370/s59279892.txt
        's59768032': 'recommendations',  # files/p13/p13249077/s59768032.txt
        's57936451': 'indication',  # files/p14/p14325424/s57936451.txt
        's50058765': 'indication',  # files/p14/p14731346/s50058765.txt
        's53356173': 'examination',  # files/p15/p15898350/s53356173.txt
        's53202765': 'technique',  # files/p16/p16076182/s53202765.txt
        's50808053': 'technique',  # files/p16/p16631485/s50808053.txt
        's51966317': 'indication',  # files/p10/p10817099/s51966317.txt
        's50743547': 'examination',  # files/p11/p11388341/s50743547.txt
        's56451190': 'note',  # files/p11/p11842879/s56451190.txt
        's59067458': 'recommendations',  # files/p11/p11984647/s59067458.txt
        's59215320': 'examination',  # files/p12/p12408912/s59215320.txt
        's55124749': 'indication',  # files/p12/p12428492/s55124749.txt
        's54365831': 'indication',  # files/p13/p13876470/s54365831.txt
        's59087630': 'recommendations',  # files/p14/p14267880/s59087630.txt
        's58157373': 'recommendations',  # files/p15/p15032392/s58157373.txt
        's56482935': 'recommendations',  # files/p15/p15388421/s56482935.txt
        's58375018': 'recommendations',  # files/p15/p15505556/s58375018.txt
        's54654948': 'indication',  # files/p17/p17090359/s54654948.txt
        's55157853': 'examination',  # files/p18/p18975498/s55157853.txt
        's51491012': 'history',  # files/p19/p19314266/s51491012.txt

    }

    custom_indices = {
        's50525523': [201, 349],  # files/p10/p10602608/s50525523.txt
        's57564132': [233, 554],  # files/p10/p10637168/s57564132.txt
        's59982525': [313, 717],  # files/p11/p11989982/s59982525.txt
        's53488209': [149, 475],  # files/p12/p12458657/s53488209.txt
        's54875119': [234, 988],  # files/p13/p13687044/s54875119.txt
        's50196495': [59, 399],  # files/p13/p13894879/s50196495.txt
        's56579911': [59, 218],  # files/p15/p15394326/s56579911.txt
        's52648681': [292, 631],  # files/p15/p15666238/s52648681.txt
        's59889364': [172, 453],  # files/p15/p15835529/s59889364.txt
        's53514462': [73, 377],  # files/p16/p16297706/s53514462.txt
        's59505494': [59, 450],  # files/p16/p16730991/s59505494.txt
        's53182247': [59, 412],  # files/p16/p16770442/s53182247.txt
        's51410602': [47, 320],  # files/p17/p17069955/s51410602.txt
        's56412866': [522, 822],  # files/p17/p17612000/s56412866.txt
        's54986978': [59, 306],  # files/p17/p17912487/s54986978.txt
        's59003148': [262, 505],  # files/p17/p17916384/s59003148.txt
        's57150433': [61, 394],  # files/p18/p18335791/s57150433.txt
        's56760320': [219, 457],  # files/p18/p18418794/s56760320.txt
        's59562049': [158, 348],  # files/p18/p18502016/s59562049.txt
        's52674888': [145, 296],  # files/p19/p19381919/s52674888.txt
        's55258338': [192, 568],  # files/p13/p13719117/s55258338.txt
        's59330497': [140, 655],  # files/p15/p15479218/s59330497.txt
        's52119491': [179, 454],  # files/p17/p17959278/s52119491.txt
        # below have no findings at all in the entire report
        's58235663': [0, 0],  # files/p11/p11573679/s58235663.txt
        's50798377': [0, 0],  # files/p12/p12632853/s50798377.txt
        's54168089': [0, 0],  # files/p14/p14463099/s54168089.txt
        's53071062': [0, 0],  # files/p15/p15774521/s53071062.txt
        's56724958': [0, 0],  # files/p16/p16175671/s56724958.txt
        's54231141': [0, 0],  # files/p16/p16312859/s54231141.txt
        's53607029': [0, 0],  # files/p17/p17603668/s53607029.txt
        's52035334': [0, 0],  # files/p19/p19349312/s52035334.txt
    }

    return custom_section_names, custom_indices

# %%
import csv
import json
import logging
import os
import re

import imagesize
import spacy
import torch
from tqdm import tqdm

# from paths import path_chest_imagenome, path_mimic_cxr, path_mimic_cxr_jpg, path_full_dataset
path_chest_imagenome = "datasets/chest-imagenome-dataset"
path_mimic_cxr = "datasets/mimic-cxr"
path_mimic_cxr_jpg = "datasets/mimic-cxr-jpg"
path_full_dataset = "datasets/dataset-with-reference-reports"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# to log certain statistics during dataset creation
txt_file_for_logging = "log_file_dataset_creation.txt"

logging.basicConfig(level=logging.INFO, format="[%(levelname)s]: %(message)s")
log = logging.getLogger(__name__)


NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES = 10000

class DataPreprocessing:
    def __init__(self,train_only = False):
        self.path_chest_imagenome = path_chest_imagenome
        self.path_mimic_cxr = path_mimic_cxr
        self.path_mimic_cxr_jpg = path_mimic_cxr_jpg
        self.path_full_dataset = path_full_dataset

        self.path_to_images_to_avoid = os.path.join(self.path_chest_imagenome, "silver_dataset", "splits", "images_to_avoid.csv")

        self.image_ids_to_avoid = self.get_images_to_avoid()

        if train_only:
            self.csv_files_dict = self.get_train_files()
        else:
            self.csv_files_dict = self.get_train_val_test_csv_files()
    def get_train_files(self):
        """Return a dict with datasets as keys and paths to the corresponding csv files in the chest-imagenome dataset as values"""
        path_to_splits_folder = os.path.join(path_chest_imagenome, "silver_dataset", "splits")
        return {dataset: os.path.join(path_to_splits_folder, dataset) + ".csv" for dataset in ["train"]}
    def get_train_val_files(self):
        """Return a dict with datasets as keys and paths to the corresponding csv files in the chest-imagenome dataset as values"""
        path_to_splits_folder = os.path.join(path_chest_imagenome, "silver_dataset", "splits")
        return {dataset: os.path.join(path_to_splits_folder, dataset) + ".csv" for dataset in ["train", "valid"]}
    def get_train_val_test_csv_files(self):
        """Return a dict with datasets as keys and paths to the corresponding csv files in the chest-imagenome dataset as values"""
        path_to_splits_folder = os.path.join(self.path_chest_imagenome, "silver_dataset", "splits")
        return {dataset: os.path.join(path_to_splits_folder, dataset) + ".csv" for dataset in ["train", "valid", "test"]}
    def get_images_to_avoid(self):
        image_ids_to_avoid = set()

        with open(self.path_to_images_to_avoid) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=",")

            # print header line
            print(next(csv_reader))

            for row in csv_reader:
                image_id = row[2]
                image_ids_to_avoid.add(image_id)

        return image_ids_to_avoid
    def create_new_csv_files(self):
        if os.path.exists(self.path_full_dataset):
            log.error(f"Full dataset folder already exists at {self.path_full_dataset}.")
            log.error("Delete dataset folder or rename variable path_full_dataset in src/path_datasets_and_weights.py before running script to create new folder!")
            return None

        os.mkdir(self.path_full_dataset)
        for dataset, path_csv_file in self.csv_files_dict.items():
            self.create_new_csv_file(dataset, path_csv_file)

    def create_new_csv_file(self, dataset, path_csv_file):
        log.info(f"Creating new {dataset}.csv file...")

        csv_rows = self.get_rows(dataset, path_csv_file, self.image_ids_to_avoid)

        self.write_rows_in_new_csv_file(dataset, csv_rows)

    def check_coordinate(self,coordinate: int) -> int:
        if coordinate < 0:
            coordinate = 0
        return coordinate
    def coordinates_faulty(self,height, width, x1, y1, x2, y2) -> bool:
        area_of_bbox_is_zero = x1 == x2 or y1 == y2
        smaller_than_zero = x2 <= 0 or y2 <= 0
        exceeds_limits = x1 >= width or y1 >= height

        return area_of_bbox_is_zero or smaller_than_zero or exceeds_limits
    def determine_if_abnormal(self,attributes_list: list[list]) -> bool:
        for attributes in attributes_list:
            for attribute in attributes:
                if attribute == "nlp|yes|abnormal":
                    return True
        return False

    def convert_phrases_to_single_string(self,phrases: list[str], sentence_tokenizer) -> str:
        def remove_substrings(phrases):
            def remove_wet_read(phrases):
                index_slices_to_remove = []
                for index in range(len(phrases)):
                    if phrases[index:index + 8] == "WET READ":

                        for curr_index in range(index + 8, len(phrases)):
                            if phrases[curr_index:curr_index + 2] in ["AM", "PM"] or phrases[curr_index:curr_index + 8] == "WET READ":
                                break

                        if phrases[curr_index:curr_index + 2] in ["AM", "PM"]:
                            index_slices_to_remove.append((index, curr_index + 2))

                for indices_tuple in reversed(index_slices_to_remove):
                    start_index, end_index = indices_tuple
                    phrases = phrases[:start_index] + phrases[end_index:]

                return phrases

            phrases = remove_wet_read(phrases)
            phrases = re.sub(SUBSTRINGS_TO_REMOVE, "", phrases, flags=re.DOTALL)

            return phrases

        def remove_whitespace(phrases):
            phrases = " ".join(phrases.split())
            return phrases

        def capitalize_first_word_in_sentence(phrases, sentence_tokenizer):
            sentences = sentence_tokenizer(phrases).sents

            phrases = " ".join(sent.text[0].upper() + sent.text[1:] for sent in sentences)

            return phrases

        def remove_duplicate_sentences(phrases):
            if phrases[-1] == ".":
                phrases = phrases[:-1]

            phrases_dict = {phrase: None for phrase in phrases.split(". ")}

            phrases = ". ".join(phrase for phrase in phrases_dict)

            return phrases + "."

        phrases = " ".join(phrases)

        phrases = remove_substrings(phrases)

        phrases = remove_whitespace(phrases)

        phrases = capitalize_first_word_in_sentence(phrases, sentence_tokenizer)

        phrases = remove_duplicate_sentences(phrases)

        return phrases

    def get_attributes_dict(self,image_scene_graph: dict, sentence_tokenizer) -> dict[tuple]:
        attributes_dict = {}
        for attribute in image_scene_graph["attributes"]:
            region_name = attribute["bbox_name"]

            if region_name not in ANATOMICAL_REGIONS:
                continue

            phrases = self.convert_phrases_to_single_string(attribute["phrases"], sentence_tokenizer)
            is_abnormal = self.determine_if_abnormal(attribute["attributes"])

            attributes_dict[region_name] = (phrases, is_abnormal)

        return attributes_dict

    def get_reference_report(self,subject_id: str, study_id: str, missing_reports: list[str]):
        custom_section_names, custom_indices = sp.custom_mimic_cxr_rules()

        if f"s{study_id}" in custom_section_names or f"s{study_id}" in custom_indices:
            return -1

        path_to_report = os.path.join(path_mimic_cxr, "files", f"p{subject_id[:2]}", f"p{subject_id}", f"s{study_id}.txt")

        if not os.path.exists(path_to_report):
            shortened_path_to_report = os.path.join(f"p{subject_id[:2]}", f"p{subject_id}", f"s{study_id}.txt")
            missing_reports.append(shortened_path_to_report)
            return -1

        with open(path_to_report) as f:
            report = "".join(f.readlines())

        sections, section_names, _ = sp.section_text(report)

        if "findings" in section_names:
            findings_index = len(section_names) - section_names[-1::-1].index("findings") - 1
            report = sections[findings_index]
        else:
            return -1

        report = " ".join(report.split())

        return report

    def get_total_num_rows(self,path_csv_file: str) -> int:
        with open(path_csv_file) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=",")

            next(csv_reader)

            return sum(1 for row in csv_reader)

    def get_rows(self, dataset: str, path_csv_file: str, image_ids_to_avoid: set) -> list[list]:

        csv_rows = []
        num_rows_created = 0

        # we split the test set into 1 that contains all images that have bbox coordinates for all 29 regions
        # (which will be around 31271 images in total, or around 95% of all test set images),
        # and 1 that contains the rest of the images (around 1440 images) that do not have bbox coordinates for all 29 regions
        # this is done such that we can efficiently evaluate the first test set (since vectorized code can be written for it),
        # and evaluate the second test set a bit more inefficiently (using for loops) afterwards
        if dataset == "test":
            csv_rows_less_than_29_regions = []

        total_num_rows = self.get_total_num_rows(path_csv_file)

        # used in function convert_phrases_to_single_string
        sentence_tokenizer = spacy.load("en_core_web_trf")

        # stats will be logged in path_to_log_file
        num_images_ignored_or_avoided = 0
        num_faulty_bboxes = 0
        num_images_without_29_regions = 0
        missing_images = []
        missing_reports = []

        with open(path_csv_file) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=",")

            # skip the first line (i.e. the header line)
            next(csv_reader)

            # iterate over all rows of the given csv file (i.e. over all images), if NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES is not set to a specific value
            for row in tqdm(csv_reader, total=total_num_rows):
                subject_id = row[1]
                study_id = row[2]
                image_id = row[3]

                # all images in set IMAGE_IDS_TO_IGNORE seem to be failed x-rays and thus have to be discarded
                # (they also don't have corresponding scene graph json files anyway)
                # all images in set image_ids_to_avoid are image IDs for images in the gold standard dataset,
                # which should all be excluded from model training and validation
                if image_id in IMAGE_IDS_TO_IGNORE or image_id in image_ids_to_avoid:
                    num_images_ignored_or_avoided += 1
                    continue

                # image_file_path is of the form "files/p10/p10000980/s50985099/6ad03ed1-97ee17ee-9cf8b320-f7011003-cd93b42d.dcm"
                # i.e. f"files/p{subject_id[:2]}/p{subject_id}/s{study_id}/{image_id}.dcm"
                # since we have the MIMIC-CXR-JPG dataset, we need to replace .dcm by .jpg
                image_file_path = row[4].replace(".dcm", ".jpg")
                mimic_image_file_path = os.path.join(self.path_mimic_cxr_jpg, image_file_path)

                # for the validation and test sets, we only want to include images that have corresponding reference reports with "findings" sections
                if dataset in ["valid", "test"]:
                    reference_report = self.get_reference_report(subject_id, study_id, missing_reports)

                    # skip images that don't have a reference report with "findings" section
                    if reference_report == -1:
                        continue

                    # the reference_report will be appended to new_image_row (declared further below, which contains all information about a single image)
                    # just before new_image_row itself is appended to csv_rows (because the image could still be rejected from the validation set,
                    # if it doesn't have 29 bbox coordinates)

                chest_imagenome_scene_graph_file_path = os.path.join(self.path_chest_imagenome, "silver_dataset", "scene_graph", image_id) + "_SceneGraph.json"

                with open(chest_imagenome_scene_graph_file_path) as fp:
                    image_scene_graph = json.load(fp)

                anatomical_region_attributes = self.get_attributes_dict(image_scene_graph, sentence_tokenizer)

                # new_image_row will store all information about 1 image as a row in the csv file
                new_image_row = [subject_id, study_id, image_id, mimic_image_file_path]
                bbox_coordinates = []
                bbox_labels = []
                bbox_phrases = []
                bbox_phrase_exist_vars = []
                bbox_is_abnormal_vars = []

                # counter to see if given image contains bbox coordinates for all 29 regions
                # if image does not bbox coordinates for 29 regions, it's still added to the train and test dataset,
                # but not the val dataset (see reasoning in the module docstring on top of this file)
                num_regions = 0

                region_to_bbox_coordinates_dict = {}
                # objects is a list of obj_dicts where each dict contains the bbox coordinates for a single region
                for obj_dict in image_scene_graph["objects"]:
                    region_name = obj_dict["bbox_name"]
                    # x1 = obj_dict["original_x1"]
                    # y1 = obj_dict["original_y1"]
                    # x2 = obj_dict["original_x2"]
                    # y2 = obj_dict["original_y2"]
                    x1 = obj_dict["x1"]
                    y1 = obj_dict["y1"]
                    x2 = obj_dict["x2"]
                    y2 = obj_dict["y2"]

                    region_to_bbox_coordinates_dict[region_name] = [x1, y1, x2, y2]

                for anatomical_region in ANATOMICAL_REGIONS:
                    bbox_coords = region_to_bbox_coordinates_dict.get(anatomical_region, None)

                    # if there are no bbox coordinates or they are faulty, then don't add them to image information
                    if bbox_coords is None :
                        num_faulty_bboxes += 1
                    else:
                        x1, y1, x2, y2 = bbox_coords

                        # it is possible that the bbox is only partially inside the image height and width (if e.g. x1 < 0, whereas x2 > 0)
                        # to prevent these cases from raising an exception, we set the coordinates to 0 if coordinate < 0, set to width if x-coordinate > width
                        # and set to height if y-coordinate > height
                        x1 = self.check_coordinate(x1)
                        y1 = self.check_coordinate(y1)
                        x2 = self.check_coordinate(x2)
                        y2 = self.check_coordinate(y2)

                        bbox_coords = [x1, y1, x2, y2]

                        # since background has class label 0 for object detection, shift the remaining class labels by 1
                        class_label = ANATOMICAL_REGIONS[anatomical_region] + 1

                        bbox_coordinates.append(bbox_coords)
                        bbox_labels.append(class_label)

                        num_regions += 1

                    # get bbox_phrase (describing the region inside bbox) and bbox_is_abnormal boolean variable (indicating if region inside bbox is abnormal)
                    # if there is no phrase, then the region inside bbox is normal and thus has "" for bbox_phrase (empty phrase) and False for bbox_is_abnormal
                    bbox_phrase, bbox_is_abnormal = anatomical_region_attributes.get(anatomical_region, ("", False))
                    bbox_phrase_exist = True if bbox_phrase != "" else False

                    bbox_phrases.append(bbox_phrase)
                    bbox_phrase_exist_vars.append(bbox_phrase_exist)
                    bbox_is_abnormal_vars.append(bbox_is_abnormal)

                new_image_row.extend([bbox_coordinates, bbox_labels, bbox_phrases, bbox_phrase_exist_vars, bbox_is_abnormal_vars])

                # for train set, add all images (even those that don't have bbox information for all 29 regions)
                # for val set, only add images that have bbox information for all 29 regions
                # for test set, distinguish between test set 1 that contains test set images that have bbox information for all 29 regions
                # (around 95% of all test set images)
                if dataset == "train" or (dataset in ["valid", "test"] and num_regions == 29):
                    if dataset in ["valid", "test"]:
                        new_image_row.append(reference_report)

                    csv_rows.append(new_image_row)

                    num_rows_created += 1
                # test set 2 will contain the remaining 5% of test set images, which do not have bbox information for all 29 regions
                elif dataset == "test" and num_regions != 29:
                    new_image_row.append(reference_report)
                    csv_rows_less_than_29_regions.append(new_image_row)

                if num_regions != 29:
                    num_images_without_29_regions += 1

                # break out of loop if NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES is specified
                if NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES and num_rows_created >= NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES:
                    break

        self.write_stats_to_log_file(dataset, num_images_ignored_or_avoided, missing_images, missing_reports, num_faulty_bboxes, num_images_without_29_regions)

        if dataset == "test":
            return csv_rows, csv_rows_less_than_29_regions
        else:
            return csv_rows

    def write_stats_to_log_file(self,dataset: str, num_images_ignored_or_avoided: int, missing_images: list[str], missing_reports: list[str], num_faulty_bboxes: int, num_images_without_29_regions: int):
        with open(txt_file_for_logging, "a") as f:
            f.write(f"{dataset}:\n")
            f.write(f"\tnum_images_ignored_or_avoided: {num_images_ignored_or_avoided}\n")

            f.write(f"\tnum_missing_images: {len(missing_images)}\n")
            for missing_img in missing_images:
                f.write(f"\t\tmissing_img: {missing_img}\n")

            f.write(f"\tnum_missing_reports: {len(missing_reports)}\n")
            for missing_rep in missing_reports:
                f.write(f"\t\tmissing_rep: {missing_rep}\n")

            f.write(f"\tnum_faulty_bboxes: {num_faulty_bboxes}\n")
            f.write(f"\tnum_images_without_29_regions: {num_images_without_29_regions}\n\n")

    def write_rows_in_new_csv_file(self,dataset: str, csv_rows: list[list]) -> None:
        log.info(f"Writing rows into new {dataset}.csv file...")

        if dataset == "test":
            csv_rows, csv_rows_less_than_29_regions = csv_rows

        new_csv_file_path = os.path.join(path_full_dataset, dataset)
        new_csv_file_path += ".csv" if not NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES else f"-{NUM_ROWS_TO_CREATE_IN_NEW_CSV_FILES}.csv"

        header = ["subject_id", "study_id", "image_id", "mimic_image_file_path", "bbox_coordinates", "bbox_labels", "bbox_phrases", "bbox_phrase_exists", "bbox_is_abnormal"]
        if dataset in ["valid", "test"]:
            header.append("reference_report")

        with open(new_csv_file_path, "w") as fp:
            csv_writer = csv.writer(fp)

            csv_writer.writerow(header)
            csv_writer.writerows(csv_rows)

        if dataset == "test":
            new_csv_file_path = new_csv_file_path.replace(".csv", "-2.csv")

            with open(new_csv_file_path, "w") as fp:
                csv_writer = csv.writer(fp)
                csv_writer.writerow(header)
                csv_writer.writerows(csv_rows_less_than_29_regions)

# %%
DataPreprocessor = DataPreprocessing(train_only=True)
DataPreprocessor.create_new_csv_files()
# Out:
# ['subject_id', 'study_id', 'dicom_id', 'path', 'ViewPosition']
#   6%|▌         | 10000/166521 [5:00:21<78:21:17,  1.80s/it]

# %% [markdown]
# # Test Dataloader

# %%
from detector.data_loader import F_RCNNDataset
dataset = F_RCNNDataset(dataset_path = "/content/Graduation-Project/datasets/dataset-with-reference-reports/train.csv")

# %%
from torch.utils.data import Dataset, DataLoader
data_loader_train = DataLoader(dataset=dataset, batch_size=4, shuffle=True, num_workers=4)

for batch_idx, (images, targets) in enumerate(data_loader_train):
  print("batch_idx: ",batch_idx)
  print("images: ",images)
  print("targets: ",targets)
  break

# %% [markdown]
# # Download Dataset

# %%
# -np
# !wget -r -N -c -np --user ahmed-sabry --ask-password https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/
# !zip -r /content/drive/MyDrive/MIMIC/p11.zip   ./physionet.org

# %%
# !zip -r /content/drive/MyDrive/MIMIC/p11.zip   ./physionet.org

# %%
# list all folders in the directory
import os
# import wget
import shutil
import zipfile
import pandas as pd
import numpy as np


def list_folders(directory):
    # get all folders in the directory names only
    folders = [f for f in os.listdir(directory) if os.path.isdir(os.path.join(directory, f))]
    return folders

# save all folders in pickle file
def save_folders(directory):
    folders = list_folders(directory)
    pd.to_pickle(folders, 'p11.pkl')
    return folders

# save pickle file to drive
def save_to_drive():
    shutil.copy('p11.pkl', '/content/drive/MyDrive/MIMIC/')
def download_to_drive():
    shutil.copy('/content/drive/MyDrive/MIMIC/p11.pkl','p11.pkl')




def save_downloaded_folders(loaded_folders,path):
    pd.to_pickle(loaded_folders, 'downloaded_p11.pkl')
    shutil.copy('downloaded_p11.pkl', path)
def load_downloaded_folders(path):
    # load pickle file from drive
    shutil.copy(path, 'downloaded_p11.pkl')
    loaded_folders = pd.read_pickle('downloaded_p11.pkl')
    return loaded_folders

def create_download_links(folders):
    # create download links
    download_links = []
    for folder in folders:
        download_links.append(f'https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/{folder}/')
    return download_links
def download_files(download_links,load_folders,name,max_count = 500):
    # download files
    count = 0
    for link in download_links:
        if count == max_count:
            break
        if link in load_folders:
            print(f'{link} already downloaded')
        else:
            wget_command = f"wget -r -c -N -np --user=ahmed-sabry --password='D6zQ3c@J#Be$y5_' -r --no-parent {link}"
            # Run the wget command
            # !{wget_command}
            print("\n\n----------------------------------------------------------------")
            print(f'{link} downloaded')

            count += 1
            print("total folders downloaded:  ",count)
            print("\n\n----------------------------------------------------------------")

            # mark folder as downloaded
            load_folders.append(link)
    print(f'{count} files downloaded')


    # zip download folder to drive
    # !zip -r "/content/drive/MyDrive/MIMIC/p11_subset2"   "./physionet.org"
    # # save downloaded folders
    save_downloaded_folders(load_folders,'/content/drive/MyDrive/MIMIC/downloaded_p11.pkl')

# %%
# folders = list_folders("physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/")
folders = save_folders("physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/")

print("folders: ",folders[:5])
# save pickle file to drive
save_to_drive()
# Out:
# folders:  ['p11801290', 'p11609681', 'p11980576', 'p11917817', 'p11311878']

# %%
download_to_drive()
folders = pd.read_pickle('p11.pkl')

download_links = create_download_links(folders)
downloaded_folders = []
downloaded_folders = load_downloaded_folders('/content/drive/MyDrive/MIMIC/downloaded_p11.pkl')
print("total downloaded folders:  ",len(downloaded_folders))
download_files(download_links,downloaded_folders,"p11_subset2",500)
# Out:
# total downloaded folders:   500
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11801290/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11609681/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11980576/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11917817/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11311878/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11941753/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11974484/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11674436/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11955591/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11186714/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11111264/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11655333/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11152619/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11399232/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11647220/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11305002/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11030383/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11197875/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11934114/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11894825/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11797249/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11266941/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11621682/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11328158/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11999659/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11767446/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11656588/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11598756/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11697074/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11177105/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11961238/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11538096/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11372349/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11115962/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11743110/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11286564/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11250458/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11692070/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11783881/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11655432/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11322609/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11854765/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11674792/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11422357/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11233834/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11411718/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11523168/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11735449/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11956832/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11668755/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11064691/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11393917/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11150693/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11607177/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11693935/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11945737/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11646000/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11610140/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11843475/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11100225/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11477216/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11853603/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11708353/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11596906/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11356217/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11024721/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11806971/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11120613/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11888400/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11843819/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11206216/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11452424/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11144903/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11837040/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11230804/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11455625/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11004146/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11007423/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11543836/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11651571/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11497218/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11946685/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11369863/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11616929/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11489188/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11761571/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11893091/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11308104/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11640104/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11813577/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11363644/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11398738/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11916248/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11013255/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11950373/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11648676/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11217246/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11117785/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11373596/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11374836/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11014822/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11865292/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11438173/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11496140/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11169394/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11905824/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11391368/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11733407/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11425757/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11607120/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11515907/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11986683/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11167079/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11181460/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11508953/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11027112/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11858154/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11469390/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11317376/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11310752/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11277249/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11866553/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11011872/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11456419/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11540785/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11885685/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11878738/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11738907/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11519746/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11282127/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11613878/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11745865/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11739512/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11975232/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11081194/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11383692/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11744227/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11932143/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11304758/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11543624/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11962217/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11049722/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11024922/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11175900/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11590302/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11154338/ already downloaded
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p
  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/index.html’
#
# physionet.org/files     [ <=>                ]     388  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:47:57 (77.3 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/index.html’ saved [388]
#
# Loading robots.txt; please ignore errors.
# --2024-02-05 16:47:57--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2024-02-05 16:47:57--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:47:57 (92.3 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/index.html’ saved [599]
#
# --2024-02-05 16:47:57--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/059c0a91-b3ab08cc-d25f5e2f-3ca79e0b-c7e7fb41.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1916375 (1.8M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/059c0a91-b3ab08cc-d25f5e2f-3ca79e0b-c7e7fb41.jpg’
#
# physionet.org/files 100%[===================>]   1.83M   860KB/s    in 2.2s
#
# 2024-02-05 16:47:59 (860 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/059c0a91-b3ab08cc-d25f5e2f-3ca79e0b-c7e7fb41.jpg’ saved [1916375/1916375]
#
# --2024-02-05 16:47:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/b82c3b8f-c6da9779-24bbcf37-0a97b0f2-db18a6bb.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2304172 (2.2M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/b82c3b8f-c6da9779-24bbcf37-0a97b0f2-db18a6bb.jpg’
#
# physionet.org/files 100%[===================>]   2.20M   858KB/s    in 2.6s
#
# 2024-02-05 16:48:02 (858 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/s56750309/b82c3b8f-c6da9779-24bbcf37-0a97b0f2-db18a6bb.jpg’ saved [2304172/2304172]
#
# FINISHED --2024-02-05 16:48:02--
# Total wall clock time: 5.6s
# Downloaded: 4 files, 4.0M in 4.8s (859 KB/s)
#
#
# ----------------------------------------------------------------
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11883857/ downloaded
# total folders downloaded:   17
#
#
# ----------------------------------------------------------------
# --2024-02-05 16:48:02--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/index.html’
#
# physionet.org/files     [ <=>                ]     503  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:02 (94.2 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/index.html’ saved [503]
#
# Loading robots.txt; please ignore errors.
# --2024-02-05 16:48:02--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2024-02-05 16:48:02--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:03 (101 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/index.html’ saved [599]
#
# --2024-02-05 16:48:03--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:03 (107 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/index.html’ saved [599]
#
# --2024-02-05 16:48:03--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/0a6a2c7e-9b0d38eb-d1f5f6dc-33e5c1e2-3348eb71.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1635423 (1.6M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/0a6a2c7e-9b0d38eb-d1f5f6dc-33e5c1e2-3348eb71.jpg’
#
# physionet.org/files 100%[===================>]   1.56M   846KB/s    in 1.9s
#
# 2024-02-05 16:48:05 (846 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/0a6a2c7e-9b0d38eb-d1f5f6dc-33e5c1e2-3348eb71.jpg’ saved [1635423/1635423]
#
# --2024-02-05 16:48:05--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/d93f7dd4-8e444084-c4806aa1-011445a3-5d07980f.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2201142 (2.1M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/d93f7dd4-8e444084-c4806aa1-011445a3-5d07980f.jpg’
#
# physionet.org/files 100%[===================>]   2.10M   876KB/s    in 2.5s
#
# 2024-02-05 16:48:07 (876 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s58589768/d93f7dd4-8e444084-c4806aa1-011445a3-5d07980f.jpg’ saved [2201142/2201142]
#
# --2024-02-05 16:48:07--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/02429626-4da0aca9-6d4967d0-741e0012-3e5f2893.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1448395 (1.4M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/02429626-4da0aca9-6d4967d0-741e0012-3e5f2893.jpg’
#
# physionet.org/files 100%[===================>]   1.38M   853KB/s    in 1.7s
#
# 2024-02-05 16:48:09 (853 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/02429626-4da0aca9-6d4967d0-741e0012-3e5f2893.jpg’ saved [1448395/1448395]
#
# --2024-02-05 16:48:09--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/21b572e6-41ce038f-dcd452f6-f47cf687-ff36949f.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 987974 (965K) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/21b572e6-41ce038f-dcd452f6-f47cf687-ff36949f.jpg’
#
# physionet.org/files 100%[===================>] 964.82K   872KB/s    in 1.1s
#
# 2024-02-05 16:48:10 (872 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/s59448395/21b572e6-41ce038f-dcd452f6-f47cf687-ff36949f.jpg’ saved [987974/987974]
#
# FINISHED --2024-02-05 16:48:10--
# Total wall clock time: 8.2s
# Downloaded: 7 files, 6.0M in 7.1s (862 KB/s)
#
#
# ----------------------------------------------------------------
# https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11237402/ downloaded
# total folders downloaded:   18
#
#
# ----------------------------------------------------------------
# --2024-02-05 16:48:10--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/index.html’
#
# physionet.org/files     [ <=>                ]     618  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:11 (118 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/index.html’ saved [618]
#
# Loading robots.txt; please ignore errors.
# --2024-02-05 16:48:11--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2024-02-05 16:48:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/index.html’
#
# physionet.org/files     [ <=>                ]     752  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:11 (123 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/index.html’ saved [752]
#
# --2024-02-05 16:48:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s54115932/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s54115932/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:11 (116 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s54115932/index.html’ saved [599]
#
# --2024-02-05 16:48:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s57855806/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s57855806/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-02-05 16:48:11 (132 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s57855806/index.html’ saved [599]
#
# --2024-02-05 16:48:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/78a030f4-31e0bc49-420e4847-a238c38d-41ec4a0b.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1578813 (1.5M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/78a030f4-31e0bc49-420e4847-a238c38d-41ec4a0b.jpg’
#
# physionet.org/files 100%[===================>]   1.50M   881KB/s    in 1.8s
#
# 2024-02-05 16:48:13 (881 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/78a030f4-31e0bc49-420e4847-a238c38d-41ec4a0b.jpg’ saved [1578813/1578813]
#
# --2024-02-05 16:48:13--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/cb65ae8a-ab445e98-cf1d7f1b-534cb3af-9967b45b.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950494 (1.9M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/cb65ae8a-ab445e98-cf1d7f1b-534cb3af-9967b45b.jpg’
#
# physionet.org/files 100%[===================>]   1.86M   908KB/s    in 2.1s
#
# 2024-02-05 16:48:15 (908 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/cb65ae8a-ab445e98-cf1d7f1b-534cb3af-9967b45b.jpg’ saved [1950494/1950494]
#
# --2024-02-05 16:48:15--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/f5c4974a-ffa8b574-a5c8c24f-7b24f80d-60e3baac.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1624333 (1.5M) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/f5c4974a-ffa8b574-a5c8c24f-7b24f80d-60e3baac.jpg’
#
# physionet.org/files 100%[===================>]   1.55M   895KB/s    in 1.8s
#
# 2024-02-05 16:48:17 (895 KB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s51665422/f5c4974a-ffa8b574-a5c8c24f-7b24f80d-60e3baac.jpg’ saved [1624333/1624333]
#
# --2024-02-05 16:48:17--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s54115932/023a4ae2-1fec3516-40d3ff9c-5b6df6d7-a00064a2.jpg
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 858499 (838K) [image/jpeg]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11482354/s54115932/023a4ae2-1fec3516-40d3ff9c-5b6df6d7-a00064a2.jpg’
#
#        physionet.or  65%[============>       ] 551.62K   878KB/s

# %%
# !zip -r "/content/drive/MyDrive/MIMIC/p11_subset2"   "./physionet.org"
