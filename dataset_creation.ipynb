# %%
# !wget -r -N -c -np --user ahmed-sabry --ask-password https://physionet.org/files/mimic-cxr/2.0.0/
# #D6zQ3c@J#Be$y5_

# %%
# to connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import shutil
# !wget -r -N -c -np --user ahmedhosny2024 --ask-password https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/
# Out:
# Streaming output truncated to the last 5000 lines.
# 2023-12-09 16:20:11 (81.4 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10092355/index.html’ saved [388]
#
# --2023-12-09 16:20:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10092782/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10092782/index.html’
#
# physionet.org/files     [ <=>                ]     388  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-12-09 16:20:11 (71.8 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10092782/index.html’ saved [388]
#
# --2023-12-09 16:20:11--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10092870/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# ...

# %%
# !zip -r /content/physionet.org/p10.zip   /content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10
# Out:
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/ (stored 0%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10152086/ (stored 0%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10152086/index.html (deflated 75%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10015860/ (stored 0%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10015860/index.html (deflated 73%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10129384/ (stored 0%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10129384/index.html (deflated 60%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10014078/ (stored 0%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10014078/index.html (deflated 60%)
#   adding: content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10064176/ (stored 0%)
# ...

# %%
# !cp /content/physionet.org/p10.zip /content/drive/MyDrive/MIMIC/ -r

# %%
import os
import random
import shutil

# list names of subfolders in a given folder
def list_subfolders_names(path):
    return [f.name for f in os.scandir(path) if f.is_dir()]
folders=list_subfolders_names("/content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p15")
# get folder form this list with probability x until size of the list = y% from subfolders size
def get_folders_to_delete(list_folders, x, y):
    list_folders_to_delete=set()
    while len(list_folders_to_delete) < (y*x):
        folder = random.choice(list_folders)
        list_folders_to_delete.add(folder)
    return list_folders_to_delete
folders_to_delete = get_folders_to_delete(folders, 0.85, len(folders))
# delete folders from os which returned in folders to delete
def delete_folders(list_folders_to_delete):
    for folder in list_folders_to_delete:
        shutil.rmtree("/content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p15/"+folder)
delete_folders(folders_to_delete)

# %% [markdown]
# # New Section

# %%
# !zip -r /content/physionet.org/Subp10.zip   /content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10

# %%
# !cp /content/physionet.org/p10.zip /content/drive/MyDrive/MIMIC/Subset -r

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# Algorithm to get subset from dataset.
#
# 1.   create dataset for each subset from 10 subsets p10
# 2.   for each subset get x% of datasets of subfoldes
# 3.   for each sunbset
#      1. get sub folders name in list
#      2. with probability x select folder i and put it in delete list until we have size of delete list = y% from subfolders size
#      3. apply action delete
#      4. upload to drive
