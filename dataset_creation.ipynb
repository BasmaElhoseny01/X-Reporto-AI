  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916882/s55465339/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916882/s55465339/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:58 (84.1 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916882/s55465339/index.html’ saved [446]
#
# --2023-11-29 13:29:58--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s55469142/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s55469142/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:59 (86.7 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s55469142/index.html’ saved [446]
#
# --2023-11-29 13:29:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56228555/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56228555/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:59 (83.7 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56228555/index.html’ saved [446]
#
# --2023-11-29 13:29:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56923749/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56923749/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:59 (123 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s56923749/index.html’ saved [446]
#
# --2023-11-29 13:29:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s59063243/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s59063243/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:59 (108 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19916931/s59063243/index.html’ saved [599]
#
# --2023-11-29 13:29:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917153/s59053013/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917153/s59053013/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:29:59 (113 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917153/s59053013/index.html’ saved [599]
#
# --2023-11-29 13:29:59--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s51758760/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s51758760/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:00 (91.5 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s51758760/index.html’ saved [599]
#
# --2023-11-29 13:30:00--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s56484188/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s56484188/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:00 (107 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917249/s56484188/index.html’ saved [599]
#
# --2023-11-29 13:30:00--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917318/s53583881/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917318/s53583881/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:00 (55.3 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917318/s53583881/index.html’ saved [599]
#
# --2023-11-29 13:30:00--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s51024830/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s51024830/index.html’
#
# physionet.org/files     [ <=>                ]     599  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:00 (112 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s51024830/index.html’ saved [599]
#
# --2023-11-29 13:30:00--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s52241024/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s52241024/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:01 (88.5 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s52241024/index.html’ saved [446]
#
# --2023-11-29 13:30:01--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s54263073/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s54263073/index.html’
#
# physionet.org/files     [ <=>                ]     446  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-11-29 13:30:01 (90.8 MB/s) - ‘physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s54263073/index.html’ saved [446]
#
# --2023-11-29 13:30:01--  https://physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/p19917410/s54738213/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response...

# %%
# to connect to drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !zip -r /content/drive/MyDrive/MIMIC/p19.zip   ./physionet.org

# %%
import os
import random
import shutil

# list names of subfolders in a given folder
def list_subfolders_names(path):
    return [f.name for f in os.scandir(path) if f.is_dir()]
folders=list_subfolders_names("/content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19")
# get folder form this list with probability x until size of the list = y% from subfolders size
def get_folders_to_delete(list_folders, x, y):
    list_folders_to_delete=set()
    while len(list_folders_to_delete) < (y*x):
        folder = random.choice(list_folders)
        list_folders_to_delete.add(folder)
    return list_folders_to_delete
folders_to_delete = get_folders_to_delete(folders, 0.85, len(folders))
# delete folders from os which returned in folders to delete
def delete_folders(list_folders_to_delete):
    for folder in list_folders_to_delete:
        shutil.rmtree("/content/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p19/"+folder)
delete_folders(folders_to_delete)

# %% [markdown]
# # New Section

# %%
# !zip -r /content/drive/MyDrive/MIMIC/Subset/p19.zip   ./physionet.org

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# Algorithm to get subset from dataset.
#
# 1.   create dataset for each subset from 10 subsets p10
# 2.   for each subset get x% of datasets of subfoldes
# 3.   for each sunbset
#      1. get sub folders name in list
#      2. with probability x select folder i and put it in delete list until we have size of delete list = y% from subfolders size
#      3. apply action delete
#      4. upload to drive
